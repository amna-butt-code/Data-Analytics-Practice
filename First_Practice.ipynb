# %%
a=5
b=2
print("Addition:" , a+b)
# Out:
# Addition: 7

# %%
numbers = [1,2,3,4,5]
print("Numbers:",numbers)
# Out:
# Numbers: [1, 2, 3, 4, 5]

# %%
import pandas
import numpy
import matplotlib
import seaborn
